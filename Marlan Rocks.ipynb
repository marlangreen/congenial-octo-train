# %% [markdown]
# # This is a heading for my first markdown document
# * this is a bullet
# * this ia another bullet
#
# THis is some text.

# %%
print("Marlan is a dork."")
# Out:
#   File "<ipython-input-2-436e833b16ef>", line 1
#     print("Marlan is a dork."")
#                                ^
# SyntaxError: EOL while scanning string literal

# %%
print("Marlan is a dork.")
# Out:
# Marlan is a dork.
